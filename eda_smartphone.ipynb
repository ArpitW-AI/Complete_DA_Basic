# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E://arpit//study//projects//sele_beau_webscrap_1//clean_smartphone.csv')

# %%
df.head()
# Out:
#      brand                  name  rating    price  has_Vo5G  has_nfc  has_ir  \
# 0     oppo   OPPO Reno 14 Pro 5G      90  49999.0     False     True    True
# 1      ai+           Ai+ Nova 5G      67   7999.0     False    False   False
# 2     oppo       OPPO Reno 14 5G      88  37999.0     False     True    True
# 3  oneplus  OnePlus Nord CE 5 5G      82  24999.0     False    False    True
# 4     oppo  OPPO Reno 14 Pro 5G       91  54999.0     False     True    True
#
#   processor_brand       processor_name  processor_core  ...  card  \
# 0       dimensity       Dimensity 8450               8  ...   NaN
# 1          unisoc         Unisoc T8200               8  ...   1.0
# 2       dimensity       Dimensity 8350               8  ...   NaN
# 3       dimensity  Dimensity 8350 Apex               8  ...   1.0
# 4       dimensity       Dimensity 8450               8  ...   NaN
#
#    num_rear_cam  num_front_cam  rear_primary_lens  front_primary_lens  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               843 non-null    object
#  1   name                843 non-null    object
#  2   rating              843 non-null    int64
#  3   price               843 non-null    float64
#  4   has_Vo5G            843 non-null    bool
#  5   has_nfc             843 non-null    bool
#  6   has_ir              843 non-null    bool
#  7   processor_brand     843 non-null    object
#  8   processor_name      843 non-null    object
#  9   processor_core      843 non-null    int64
#  10  processor_speed     779 non-null    float64
#  11  ram_size            840 non-null    float64
#  12  rom                 840 non-null    float64
#  13  battery_capacity    799 non-null    float64
#  14  charging_speed      799 non-null    float64
# ...

# %%
df['ppi']=df['ppi'].round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               843 non-null    object
#  1   name                843 non-null    object
#  2   rating              843 non-null    int64
#  3   price               843 non-null    float64
#  4   has_Vo5G            843 non-null    bool
#  5   has_nfc             843 non-null    bool
#  6   has_ir              843 non-null    bool
#  7   processor_brand     843 non-null    object
#  8   processor_name      843 non-null    object
#  9   processor_core      843 non-null    int64
#  10  processor_speed     779 non-null    float64
#  11  ram_size            840 non-null    float64
#  12  rom                 840 non-null    float64
#  13  battery_capacity    799 non-null    float64
#  14  charging_speed      799 non-null    float64
# ...

# %% [markdown]
# ## 📊 Categorical Features
# `brand`, `processor_brand`, `new_os`, `resolution`
#
# ## ✅ Boolean Features
# `has_Vo5G`, `has_nfc`, `has_ir`
#
# ## 🔢 Numerical Features
# `rating`, `price`, `processor_core`, `processor_speed`, `ram_size`, `rom`, `battery_capacity`, `charging_speed`, `screen_size`, `refresh_rate`, `extended_upto`, `card`, `num_rear_cam`, `num_front_cam`, `rear_primary_lens`, `front_primary_lens`, `width`, `height`, `ppi`

# %%
temp_df=df.groupby('brand').count()['name']

# %%
temp_df[temp_df>10].plot(kind='bar')
plt.show()

# %%
temp_df[temp_df>10].plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='name'>

# %%
df['rating'].describe()
# Out:
# count    843.000000
# mean      81.310795
# std        5.416454
# min       58.000000
# 25%       78.000000
# 50%       82.000000
# 75%       85.000000
# max       96.000000
# Name: rating, dtype: float64

# %%
df['rating'].skew()
# Out:
# np.float64(-0.216039648605981)

# %%
sns.histplot(data=df, x='rating', kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df['price'].describe()
# Out:
# count       843.000000
# mean      31490.831554
# std       27336.230998
# min        7699.000000
# 25%       15449.500000
# 50%       22768.000000
# 75%       34999.000000
# max      185999.000000
# Name: price, dtype: float64

# %%
sns.histplot(data=df, x='price', kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data=df, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
num_col=df.select_dtypes(include=['int64', 'float']).columns
# Out:
# Index(['rating', 'price', 'processor_core', 'processor_speed', 'ram_size',
#        'rom', 'battery_capacity', 'charging_speed', 'screen_size',
#        'refresh_rate', 'extended_upto', 'card', 'num_rear_cam',
#        'num_front_cam', 'rear_primary_lens', 'front_primary_lens', 'width',
#        'height', 'ppi'],
#       dtype='object')

# %%
for i in num_col:

    plt.figure(figsize=(12,4))
    
    plt.subplot(1,2,1)
    sns.histplot(data=df, x=i, fill=True ,kde=True)
   
    plt.subplot(1,2,2)
    sns.boxplot(x=df[i])

    plt.tight_layout()
    plt.show()

# %%
df['processor_core'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='processor_core'>

# %%
df['processor_brand'].value_counts().head().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['new_os'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['processor_core'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='processor_core'>

# %%
df['ram_size'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['rom'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['charging_speed'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['num_front_cam'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['num_rear_cam'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['resolution'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['has_Vo5G'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['has_nfc'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['has_ir'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['refresh_rate'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Bivariate

# %%
new_temp=temp_df[temp_df>10]

# %%
new_temp
# Out:
# brand
# apple        35
# google       17
# infinix      27
# iqoo         41
# lava         21
# motorola     40
# nothing      12
# oneplus      39
# oppo         60
# poco         43
# realme      132
# samsung     142
# tecno        29
# vivo        104
# xiaomi       68
# Name: name, dtype: int64

# %%
new=df.groupby('brand')['price'].mean()

# %%
latest=new[new_temp.index].reset_index()

# %%
latest
# Out:
#        brand         price
# 0      apple  94018.085714
# 1     google  62263.705882
# 2    infinix  18994.592593
# 3       iqoo  25879.731707
# 4       lava  13159.333333
# 5   motorola  27037.650000
# 6    nothing  35736.333333
# 7    oneplus  40363.564103
# 8       oppo  28501.433333
# 9       poco  17701.186047
# 10    realme  21474.393939
# 11   samsung  41885.866197
# 12     tecno  21118.000000
# 13      vivo  29108.259615
# 14    xiaomi  24230.117647

# %%
plt.figure(figsize=(10,7))
sns.barplot(data=latest, x='brand', y='price')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=df, x='rating', y='price', hue='new_os', size='resolution')
plt.show()

# %%
df.head()
# Out:
#      brand                  name  rating    price  has_Vo5G  has_nfc  has_ir  \
# 0     oppo   OPPO Reno 14 Pro 5G      90  49999.0     False     True    True
# 1      ai+           Ai+ Nova 5G      67   7999.0     False    False   False
# 2     oppo       OPPO Reno 14 5G      88  37999.0     False     True    True
# 3  oneplus  OnePlus Nord CE 5 5G      82  24999.0     False    False    True
# 4     oppo  OPPO Reno 14 Pro 5G       91  54999.0     False     True    True
#
#   processor_brand       processor_name  processor_core  ...  card  \
# 0       dimensity       Dimensity 8450               8  ...   NaN
# 1          unisoc         Unisoc T8200               8  ...   1.0
# 2       dimensity       Dimensity 8350               8  ...   NaN
# 3       dimensity  Dimensity 8350 Apex               8  ...   1.0
# 4       dimensity       Dimensity 8450               8  ...   NaN
#
#    num_rear_cam  num_front_cam  rear_primary_lens  front_primary_lens  \
# ...

# %%
sns.barplot(data=df ,x='has_nfc', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='has_Vo5G', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='has_ir', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='processor_core', y='price',estimator=np.median)
plt.show()

# %%
pd.crosstab(df['processor_core'], df['new_os'])
# Out:
# new_os          android  ios
# processor_core
# 6                     0   35
# 8                   796    0
# 9                     5    0
# 10                    7    0

# %%
pd.crosstab(df['new_os'], df['has_Vo5G'])
# Out:
# has_Vo5G  False  True
# new_os
# android     704    104
# ios          35      0

# %%
sns.barplot(data=df ,x='ram_size', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='rom', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='resolution', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='new_os', y='price',estimator=np.median)
plt.show()

# %%
sns.barplot(data=df ,x='has_nfc', y='price',estimator=np.median, hue='has_ir')
# Out:
# <Axes: xlabel='has_nfc', ylabel='price'>
